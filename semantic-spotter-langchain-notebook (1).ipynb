# %% [markdown]
# ## Setup

# %%
# install required packages
#!pip install -q openai langchain chromadb faiss-cpu pypdf tiktoken docarray

# %% [markdown]
# ## Set the OpenAI Key

# %%
# import the necessary libraies
import os
import openai

folder_path = r"C:\Users\hp\Downloads\OpenAI_API_Key.txt"

# Read the text file containing the API key
with open(folder_path, "r") as f:
  openai.api_key = ' '.join(f.readlines())

# Update the OpenAI API key by updating the environment variable
os.environ["OPENAI_API_KEY"] = openai.api_key

# %% [markdown]
# # **LangChain**
#
# The LangChain framework revolves around the following building blocks:
# * Model I/O: Interface with language models (LLMs & Chat Models, Prompts, Output Parsers)
# * Retrieval: Interface with application-specific data (Document loaders, Document transformers, Text embedding models, Vector stores, Retrievers)
# * Chains: Construct sequences/chains of LLM calls
# * Memory: Persist application state between runs of a chain
# * Agents: Let chains choose which tools to use given high-level directives
# * Callbacks: Log and stream intermediate steps of any chain

# %% [markdown]
# # 1. Model I/O
#
#
# LangChain's Model I/O component provides support to interface with the LLM and generate responses.
# The Model I/O consists of:
# * **Language Models**: Make calls to language models through common interfaces
# * **Prompts**: Templatize, dynamically select, and manage model inputs
# * **Output Parsers**: Extract information from model outputs
#
# The general flow of Model I/O in LangChain is illustrated in the image below ([source](https://python.langchain.com/docs/modules/model_io/)).

# %% [markdown]
# ## Model
#
#
# LangChain provides an easy out-of-the box support to work with LLMs. LangChain provides interfaces and integrations for two classes of LLM models
# *   **LLMs**: Models that take a text string as input and return a text string
# *   **Chat models**: Models that are backed by a language model but take a list of Chat Messages as input and return a Chat Message.
#
# LLMs and chat models are subtly but importantly different. LLMs in LangChain refer to pure `text completion models` - where a string prompt is taken as the input and the LLM outputs a string.
#
# Chat Models are LLMs that have been tuned specifically for having turn-based conversations such as ChatGPT. Instead of a single string, they take a list of chat messages as input. Usually these models have labelled messages such as "System", "Human" and provides a AI chat message ("AI"/ "Output Response") as the output.

# %% [markdown]
# ###  **[LLMs](https://python.langchain.com/docs/modules/model_io/models/llms/)**
#
#
# The `LLM` class of LangChain is designed to provide a standard interface for all the major LLM provides such as OpenAI, Cohere, Hugging Face, etc.
# LangChain provided a standard interface for interacting with many different LLMs to perform  standard text completion tasks.
#
# This, however, has been deprecated and no longer is supported by LangChain. The text completion model is now categorised as `legacy` by OpenAI hence for the remainder of the course, we will work with OpenAI's chat model.

# %% [markdown]
# ###  **[Chat Model](https://python.langchain.com/docs/modules/model_io/models/chat/)**
#
# Chat models are a variation on language models. While chat models use language models under the hood, the interface they use is a bit different. Rather than using a "text in, text out" API, they use an interface where "chat messages" are the inputs and outputs.
#
# The OpenAI chat model can be imported using the code below:
# ```
# pip install -qU langchain-openai
# from langchain_openai import ChatOpenAI
# ```
# There are two ways to initiate the OpenAI LLM class once the necessary libraries have been imported.
# If you'd prefer not to set an environment variable you can pass the key in directly via the openai_api_key named parameter when initiating the OpenAI LLM class:
# ```
# chat = ChatOpenAI(openai_api_key="...")
# ```
# Otherwise you can initialize without any params:
# ```
# from langchain_openai import ChatOpenAI
# chat = ChatOpenAI()
# ```

# %%
# import required libraries
from langchain_openai import ChatOpenAI, OpenAI

# instantiate OpenAI's Chat Model
llm_chat = ChatOpenAI()

# %% [markdown]
# The ChatOpenAI() can take multiple arguments. The API reference contains the complete list of arguments that can be passed to the chat model. A few important ones include:
# * max_tokens
# * model_name:  If not defined, the default model is `gpt-3.5-turbo`
# * max_retries: If not defined, the default value is 6
# * temperature: If not defined, the default value `temperature = 0.7`

# %% [markdown]
# ### **[Document Loaders](https://python.langchain.com/docs/modules/data_connection/document_loaders/)**
#
#
# Document loaders provide an easy method to import data from different sources or formats as a DOcument, which contains the text content and the associated metadata.
#
# Document Loaders load documents from different sources like HTML, PDF, text, etc., from various locations like cloud storage buckets and public websites. LangChain provides over 100 different document loaders as well as integrations with other major providers in the space, like AirByte and Unstructured. Refer to the official documentation for the complete list of supported [document loaders](https://api.python.langchain.com/en/latest/api_reference.html#module-langchain.document_loaders) in the API reference and the [official documentation](https://python.langchain.com/docs/integrations/document_loaders).
#
# It should be noted that some document loaders require the associated libraries to be installed.

# %% [markdown]
# PDF Documents

# %% [markdown]
# Langchain can load and parse PDF documents using various pdf connectors. We will see the PyPDFLoader to load documents into an array of documents. The document loader requires the python package of `pypdf` to be installed.
#
# Each document contains the page content and metadata with the associated page number.
#
# An added advantage of using PyPDFLoader is that the documents can be retrieved with page numbers.

# %%
# import the PyPDFLoader class from LangChain
from langchain_community.document_loaders import PyPDFDirectoryLoader

PDF_file = r"C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data"

# Read the insurance documents from directory
pdf_directory_loader = PyPDFDirectoryLoader(PDF_file)

documents = pdf_directory_loader.load()
print()

# %%
# print details and first 100 lines from each docucment
for doc in documents:
    print(f"Source: {doc.metadata['source']}")
    print(f"Page Number: {doc.metadata['page']}")
    print(f"Content: {doc.page_content[:100]}...")  # Displaying the first 100 characters
# Out:
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 0
# Content: Part A
# <<Date>>
# <<Policyholder’s Name>>
# <<Policyholder’s Address>>
# <<Policyholder’s Contact Num...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 1
# Content: Agency/Intermediary Contact Details:  <<Agency/Intermediary address>>
#
#
#
#
# Address for Correspon...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 2
# Content: POLICY DOCUMENT- HDFC LIFE EASY HEALTH
#
# Unique Identification Number: <<101N110V03>>
#
#  Your Poli...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 3
# Content: Date of Birth of Appointee << dd/mm/yyyy >>
# Appointee's Address <<  >>
#
# Signed at Mumbai...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 4
# Content: Part B
# Definitions
# The following capitalised terms wherever used in this Policy shall have the mea...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 5
# Content: iii. A rise in cardiac biomarkers or Troponin T or I in absence of overtischemic heart
# disease OR f...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 6
# Content: apart; and
# ii. Requiring continuous permanent supplementary oxygen therapy for hypoxemia;
# and
# i...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 7
# Content: Sclerosis
# with
# persisting
# symptoms
# all of the following:
# i. investigations including typical MR...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 8
# Content: (16)  Intensive Care Unit (ICU) - means an identified section, ward or wing of a Hospital which is u...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 9
# Content: Plan option Benefits covered
# A DHCB
# B SB
# C CIB
# D DHCB + SB
# E SB + CIB
# F DHCB + CIB
# G DHCB + S...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 10
# Content: v. In case 100% of the Sum Insured has been used up, the cover for Surgical Benefit will cease for t...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 11
# Content: ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 12
# Content: Part D
#
# 1. Claims Procedure
# You have the option to claim under the Policy subject to Policy Terms...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 13
# Content: In case you are not agreeable to any of the provisions stated in the Policy, you have the option to ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 14
# Content: Part E
# (Applicable charges, Fund name, fund options)
#
#
#                  T...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 15
# Content: Part F
#
# 1. Waiting Period
#
#  60 days waiting period
# For Daily Hospital Cash Benefit and Surgica...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 16
# Content: 7. Routine eye tests, any Dental Treatment or Surgery of cosmetic nature, extraction of impacted
# to...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 17
# Content: Assignment or transfer of this Policy shall be in accordance with Section 38 of the Insurance Act, 1...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 18
# Content: (2) We reserve the right to change any of these Policy Provisions / terms and conditions in accordan...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 19
# Content: Part G
# (Grievance Redress Mechanism)
# 1. Complaint Resolution Process
# (i) The customer can contac...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 20
# Content: (xi) If you are not satisfied with the response or do not receive a response from us within 15 days,...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 21
# Content: CHENNAI Office of the Insurance Ombudsman, Fatima Akhtar
# Court, 4th Floor, 453,  Anna Salai, Teynam...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 22
# Content: Gazipur, Jalaun, Kanpur,
# Lucknow, Unnao,
# Sitapur, Lakhimpur,
# Bahraich, Barabanki,
# Raebareli, Sra...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 23
# Content: Email: bimalokpal.pune@ecoi.co.in
#
# B. Power of Ombudsman-
# 1) The Ombudsman shall receive and con...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 24
# Content: iii. after expiry of a period of one month from the date of sending the written representation to th...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 25
# Content: Annexure I
# LIST OF 138 SURGERIES
#  The Surgeries are divided into 4 Categories depending upon the ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 26
# Content: maxillary lesions
# 33 Open excision of benign mediastinal
# lesions   54 Hysterectomy for malignant c...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 27
# Content: Cement)
# 80 Total hip replacement- Others   110 Kidney injury repair
# 81 Total Knee replacement(With...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 28
# Content: Annexure II
# Section 39 - Nomination by Policyholder Nomination of a life insurance Policy is as bel...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 29
# Content: Disclaimer: This is not a comprehensive list of amendments of Insurance Laws (Amendment) Act, 2015
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 30
# Content: Annexure III
# Provisions regarding Policy not being called into question in terms of Section 45 of t...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 31
# Content: Annexure IV
#
# Section 38 - Assignment or Transfer of Insurance Policies
# Assignment or transfer of ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Easy-Health-101N110V03-Policy-Bond-Single-Pay (1).pdf
# Page Number: 32
# Content: Disclaimer: This is not a comprehensive list of amendments of Insurance Laws (Amendment) Act, 2015
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 0
# Content: Page 1 of 31
#
# Part A
# <<Date>>
# <<Master Policyholder’s Name>>
# << Master Policyholder’s Address>...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 1
# Content: Page 2 of 31
#
# MASTER POLICY DOCUMENT- HDFC Life Group Poorna Suraksha
#
# Unique Identification Num...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 2
# Content: Page 3 of 31
#
# POLICY SCHEDULE
# 1. Master Policy Number:<< system/operations generated>>
# 2. Date...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 3
# Content: Page 4 of 31
#
#
# Part B
# Definitions
# The following capitalized terms wherever used in this Policy...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 4
# Content: Page 5 of 31
#
# i. Acute condition - Acute condition is a disease, Illness or Injury that is likely ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 5
# Content: Page 6 of 31
#
# (38) Sum Assured- means the amount payable under this Master Policy per Scheme Membe...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 6
# Content: Page 7 of 31
#
# Part C
# 1. Benefits:
#
# (1) Benefits on Death or diagnosis of contingency covered – ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 7
# Content: Page 8 of 31
#
# 21. Progressive
# Scleroderma
# 22. Muscular
# Dystrophy 23. Poliomyelitis 24. Loss of ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 8
# Content: Page 9 of 31
#
# In case if the Scheme Member surrenders the Certificate of Insurance anytime during ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 9
# Content: Page 10 of 31
#
# Part D
# 1. Additional Sum Assured option:
# The Scheme Member can opt to increase h...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 10
# Content: Page 11 of 31
#
#
# 2. Assignment or Transfer
# Assignment shall be as per the provisions of Section ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 11
# Content: Page 12 of 31
#
# thereof, within 15 days from the date of receipt of the Certificate of Insurance, a...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 12
# Content: Page 13 of 31
#
# Part E
# 1. Additional Servicing Charges
# Nil...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 13
# Content: Page 14 of 31
#
# Part F
#
# 1. Waiting Period and Exclusions:
# i. 90 Days Waiting Period for Accelera...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 14
# Content: Page 15 of 31
#
#
# Note: For the purpose of waiting period, Date of commencement or inception of cov...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 15
# Content: Page 16 of 31
#
# a. Completed claim form, (including NEFT details and bank account proof as specifie...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 16
# Content: Page 17 of 31
#
# (4) Subject to Section 45 of the Insurance Act 1938, as amended from time to time i...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 17
# Content: Page 18 of 31
#
# intimation of change of address lies with the Master Policyholder. An updated conta...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 18
# Content: Page 19 of 31
#
#
# Part G
#
# 1. Grievance Redressal Process
# (1) The Master Policyholder can contac...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 19
# Content: Page 20 of 31
#
# (1) Details and addresses of Insurance Ombudsman
#
# Office of the
# Ombudsman
# Conta...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 20
# Content: Page 21 of 31
#
# HYDERABAD Office of the Insurance Ombudsman, 6-2-46, 1st floor,
# "Moin Court", Lane...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 21
# Content: Page 22 of 31
#
# MUMBAI Office of the Insurance Ombudsman, 3rd Floor, Jeevan
# Seva Annexe,  S. V. Ro...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 22
# Content: Page 23 of 31
#
# from time to time or the terms and conditions of the policy contract, in so far as ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 23
# Content: Page 24 of 31
#
#
# Annexure I
# Section 38 - Assignment or Transfer of Insurance Policies
# Assignmen...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 24
# Content: Page 25 of 31
#
#
# Annexure II
# Section 39 - Nomination by member of the policy
# Nomination of a li...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 25
# Content: Page 26 of 31
#
# Annexure III
# Section 45 – Policy shall not be called in question on the ground of ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 26
# Content: Page 27 of 31
#
#
# Annexure IV
# Definitions of covered Critical Illnesses and surgeries
#
# 1. Myocar...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 27
# Content: Page 28 of 31
#
# 6. Alzheimer's Disease - Deterioration or loss of intellectual capacity as confirme...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 28
# Content: Page 29 of 31
#
# 13. Third Degree Burns - There must be third-degree burns with scarring that cover ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 29
# Content: Page 30 of 31
#
#  One of the following human organs: heart, lung, liver, kidney, pancreas, that res...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf
# Page Number: 30
# Content: Page 31 of 31
#
#  Clinical manifestations of anaemia, polyuria, and progressive deterioration in ki...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 0
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 0
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 1
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 1
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 2
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 2
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 3
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 3
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 4
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 4
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 5
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 5
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 6
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 6
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 7
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 7
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 8
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 8
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 9
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 9
#
# ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 10
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 10
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 11
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 11
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 12
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 12
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 13
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 13
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 14
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 14
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 15
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 15
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 16
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 16
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 17
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 17
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 18
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 18
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 19
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 19
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 20
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 20
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 21
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 21
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 22
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 22
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 23
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 23
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 24
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 24
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 25
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 25
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 26
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 26
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 27
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 27
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 28
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 28
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Group-Term-Life-Policy.pdf
# Page Number: 29
# Content: F&U dated 15th October 2022                  UIN-101N169V02  P a g e  | 29
#  ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 0
# Content: PART A: Covering Letter with Policy Schedule
# __________________                                    ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 1
# Content: A.1. Policy Preamble
#
# HDFC Life Sampoorna Jeevan  Plan is a non -linked participating individual l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 2
# Content: Stamp Duty of Rs«ADDAMT» /- is paid as provided under Article 47D(iii) of Indian Stamp Act, 1899 and...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 3
# Content: 11. Guaranteed Surrender Value (GSV) means the minimum guaranteed amount that is payable in the even...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 4
# Content: 30. Regulations mean the laws and Regulations in effect as amended from time to time and applicable ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 5
# Content: BENEFITS PAYABLE UNDER THIS POLICY
#
# C.1. Death Benefit: Subject to terms and conditions of this Po...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 6
# Content: Option A : Lump Sum Option
# 100% of Basic Sum Assured
# +
# Applicable Bonus, if declared
# +
# Applica...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 7
# Content: C.3.2. Survival Benefit payable shall also depend on the bonus option chosen by the Policyholder on ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 8
# Content: Simple Reversionary Income Bonus declared, if any, under this option shall be paid out in the manner...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 9
# Content: C.4. Payment of Premiums:  This Policy is issued subject to the Policyholder making prompt and regul...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 10
# Content: D.1.  Free Look Provisions: The Policyholder shall have a period of 15 days from the date of receipt...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 11
# Content: If at least two full years‘ Premium s have not been paid, the Policy will lapse on the expiry of Gra...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 12
# Content: D.3.1.2 Reduced Paid up – Non Guaranteed Benefit
# \
# If at least 2/3rd of total Premiums payable dur...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 13
# Content: In case the Bonus Option 4 or Bonus Option 5 have been chosen, then the applicable reduced paid -up ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 14
# Content: Any fresh loan within the permissible limits will be the difference between maximum permissible loan...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 15
# Content: E.1.  Not Applicable as this is a Non-linked individual product.
#
# PART E
# All the applicable Char...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 16
# Content: F.1. Fraud and Misstatement: In issuing this Policy, the Company has relied on, and would rely on, a...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 17
# Content: Please communicate any changes in your mailing address or any other communication details as soon as...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 18
# Content: (i) Death Certificate, in original, issued by the competent authority;
# (ii) Policy Document, in ori...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 19
# Content: Grievance Redressal Process
#
# (i) The customer can contact us on the below mentioned address or at...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 20
# Content: 2. In the event you are dissatisfied with the response provided by us, you may approach the Insuranc...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 21
# Content: GUWAHATI
# Office of the Insurance Ombudsman,
# Jeevan Nivesh, 5th Floor,
# Nr. Panbazar over bridge, S...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 22
# Content: Distt: Gautam Buddh Nagar,
# U.P-201301.
# Tel.: 0120-2514252 / 2514253
# Email: bimalokpal.noida@cioin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 23
# Content: iii. the complainant is not satisfied with the reply given to him by the insurer or insurance broker...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 24
# Content: ANNEXURE – I
#
# Section 45 – Policy shall not be called in question on the ground of misstatement af...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 25
# Content: 09. The insurer can call for proof of Age at any time if he is entitled to do so and no Policy shall...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 26
# Content: ANNEXURE – II
#
# Section 38 - Assignment and Transfer of Insurance Policies:
#
# Provisions regarding...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 27
# Content: i. the proceeds under the Policy shall become payable to Policyholder or Nominee(s) in the event of ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 28
# Content: ANNEXURE – III
#
# Section 39 – Nomination by Policyholder
#
# Provisions regarding nomination of a Po...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 29
# Content: 14. If Nominee(s) die after the Policyholder but before his share of the amount secured under the Po...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 30
# Content: ANNEXURE – IV
#
# Paid-up Addition Factor per Re. 1 Cash Bonus utilized for outstanding Policy Term o...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 31
# Content: Paid-up Addition Factor per Re. 1 Cash Bonus utilized for outstanding Policy Term of 37 to 54 years...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 32
# Content: Paid-up Addition Factor per Re. 1 Cash Bonus utilized for outstanding Policy Term of 19 to 36 years...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 33
# Content: Paid-up Addition Factor per Re. 1 Cash Bonus utilized for outstanding Policy Term of 1 to 18 years...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 34
# Content: ANNEXURE – V
#
# Cash Value Factor per Re.1 vested Paid-up Additions for Outstanding Policy Term of 5...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 35
# Content: Cash Value Factor per Re.1 vested Paid-up Additions for Outstanding Policy Term of 37 to 54 years...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 36
# Content: Cash Value Factor per Re.1 vested Paid-up Additions for Outstanding Policy Term of 19 to 36 years...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 37
# Content: Cash Value Factor per Re.1 vested Paid-up Additions for Outstanding Policy Term of 1 to 18 years...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 38
# Content: ANNEXURE – VI - The Guaranteed Surrender Value Factors...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 39
# Content: ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 40
# Content: ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 41
# Content: ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 42
# Content: ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sampoorna-Jeevan-101N158V04-Policy-Document (1).pdf
# Page Number: 43
# Content: ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 0
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 1
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 2
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 3
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 4
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 5
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 6
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 7
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 8
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 9
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 10
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 11
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 12
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 13
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 14
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 15
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 16
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 17
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 18
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 19
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 20
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 21
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 22
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 23
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 24
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 25
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Sanchay-Plus-Life-Long-Income-Option-101N134V19-Policy-Document.pdf
# Page Number: 26
# Content: HDFC Life Sanchay Plus (UIN – 101N134V19) – Appendix 9 (c) – Policy Bond
# A non-participating, non-l...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 0
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 1
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 2
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 3
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 4
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 5
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 6
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 7
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 8
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 9
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 10
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 11
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 12
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 13
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 14
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 15
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 16
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 17
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 18
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 19
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 20
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 21
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 22
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 23
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 24
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 25
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 26
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 27
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 28
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 29
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 30
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 31
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 32
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 33
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 34
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 35
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Life-Smart-Pension-Plan-Policy-Document-Online.pdf
# Page Number: 36
# Content: HDFC Life Smart Pension Plan 101L164V02 – Terms and Conditions (Direct &
# Online Sales)
# (A Unit Lin...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 0
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 1
# 01/01/2009
# Mrs. Ashwini...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 1
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 2
# HDFC SURGICARE PLAN
# Un...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 2
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 3
# SCHEDULE OF BENEFITS
#   ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 3
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 4
# SPACE FOR ENDORSEMENTS...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 4
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 5
# HDFC SURGICARE PLAN
#
# S...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 5
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 6
# specially equipped for t...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 6
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 7
# 3.  Benefits
#
# If you p...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 7
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 8
#  9 Drainage of extradura...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 8
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 9
#  47 Open surgery for par...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 9
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 10
#
# Prerequisite for Paym...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 10
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 11
# • The maximum number of...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 11
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 12
# 4.   Payment and Cessat...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 12
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 13
# • less cost of cover fo...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 13
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 14
# • Any sickness classes ...
# Source: C:\Users\hp\OneDrive\Desktop\SEMANTIC SPOTTER\Input Data\HDFC-Surgicare-Plan-101N043V01.pdf
# Page Number: 14
# Content: HDFC Standard Life Insurance Company Limited
# HDFC SurgiCare Plan
#
# 15
# Under the provisions of...

# %% [markdown]
# ### **Document Transformers / Text Splitters**
# Often times your document is too long (like a book) for your LLM. You need to split it up into chunks. Text splitters help with this.
#
# There are many ways you could split your text into chunks, experiment with [different ones](https://python.langchain.com/en/latest/modules/indexes/text_splitters.html) to see which is best for you.

# %% [markdown]
# LangChain offers different text splitters for splitting the data such as:
# * Split by Character
# * Recursive Splitter
# * Token Splitter
#
# **Split by Character** - This is the simplest method. This splits based on characters (by default "\n\n") and measure chunk length by number of characters.
# * How the text is split: by single character.
# * How the chunk size is measured: by number of characters.
#
# **Recursive Text Splitter** - This text splitter is the recommended one for generic text. It is parameterized by a list of characters. It tries to split on them in order until the chunks are small enough. The default list is ["\n\n", "\n", " ", ""]. This has the effect of trying to keep all paragraphs (and then sentences, and then words) together as long as possible, as those would generically seem to be the strongest semantically related pieces of text.
# * How the text is split: by list of characters.
# * How the chunk size is measured: by number of characters.
#
# **Split by tokens** - Language models have a token limit. You should not exceed the token limit. When you split your text into chunks it is therefore a good idea to count the number of tokens. There are many tokenizers. When you count tokens in your text you should use the same tokenizer as used in the language model.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Initialize the RecursiveCharacterTextSplitter (customize chunk size and overlap as needed)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

splits = text_splitter.split_documents(documents)

# %%
# print a sample chunk
print ("Text Preview:") # Preview the split texts and the character count
print (splits[0].page_content,"-", len(splits[0].page_content), "\n")
print (splits[1].page_content,"-", len(splits[1].page_content), "\n")
print (splits[2].page_content,"-", len(splits[2].page_content), "\n")
print (splits[3].page_content,"-", len(splits[3].page_content), "\n")
print (splits[4].page_content,"-", len(splits[4].page_content), "\n")
print (splits[5].page_content,"-", len(splits[5].page_content), "\n")
# Out:
# Text Preview:
# Part A
# <<Date>>
# <<Policyholder’s Name>>
# <<Policyholder’s Address>>
# <<Policyholder’s Contact Number>>
#
# Dear <<Policyholder’s Name>>,
#
# Sub: Your Policy no. <<  >>
# We are glad to inform you that your proposal has been accepted and the HDFC Life Easy Health (“Policy”)
# being this document, has been issued. We have made every effort to design your Policy in a simple format. We
# have highlighted items of importance so that you may recognize them easily.
#
# Policy document:
# As an evidence of the insurance contract between HDFC Life Insurance Company Limited and you, the Policy
# is enclosed herewith. Please preserve this document safely and also inform your nominees about the same. A
# copy of your proposal form and other relevant documents submitted by you is also enclosed for your
# information and record.
#
# Cancellation in the Free-Look Period:
#
# << In case you are not agreeable to any of the terms and conditions stated in the Policy, you have the option to - 979
#
# information and record.
#
# Cancellation in the Free-Look Period:
#
# << In case you are not agreeable to any of the terms and conditions stated in the Policy, you have the option to
# return the Policy to us for cancellation stating the reasons thereof, within 30 days from the date of receipt of the
# Policy as your Policy is an electronic Policy / purchased through Distance Marketing mode. On receipt of your
# letter along with the original Policy (original Policy Document is not required for policies in dematerialised
# form), we shall arrange to refund the Premium paid by you, subject to deduction of the proportionate risk
# Premium for the period of cover and the expenses incurred by us for medical examination (if any) and stamp
# duty charges. / In case you are not agreeable to any of the terms and conditions stated in the Policy, you have the
# option to return the Policy to us for cancellation stating the reasons thereof, within 15 days from the date of - 967
#
# option to return the Policy to us for cancellation stating the reasons thereof, within 15 days from the date of
# receipt of the Policy. On receipt of your letter along with the original Policy (original Policy Document is not
# required for policies in dematerialised form), we shall arrange to refund the Premium paid by you, subject to
# deduction of the proportionate risk Premium for the period of cover and the expenses incurred by us for medical
# examination (if any) and stamp duty charges. >>
#
# Contacting us:
# The address for correspondence is specified below. To enable us to serve you better, you are requested to quote
# your Policy number in all future correspondence. In case you are keen to know more about our products and
# services, we would request you to talk to our Certified Financial Consultant (Insurance Agent) who has advised
# you while taking this Policy. The details of your Certified Financial Consultant including contact details are
# listed below. - 975
#
# you while taking this Policy. The details of your Certified Financial Consultant including contact details are
# listed below.
#
# To contact us in case of any grievance, please refer to Part G. In case you are not satisfied with our response,
# you can also approach the Insurance Ombudsman in your region.
#
# Thanking you for choosing HDFC Life Insurance Company Limited and looking forward to serving you in the
# years ahead,
# Yours sincerely,
#
# << Designation of the Authorised Signatory >>
#
# Branch Address:  <<Branch Address>>
# Agency/Intermediary Code:  <<Agency/Intermediary Code>>
# Agency/Intermediary Name:  <<Agency/Intermediary Name>>
# Agency/Intermediary Telephone Number:  <<Agency/Intermediary mobile &
# landline number>> - 737
#
# Agency/Intermediary Contact Details:  <<Agency/Intermediary address>>
#
#
#
#
# Address for Correspondence: HDFC Life Insurance Company Limited, 11th Floor Lodha Excelus, Apollo
# Mills Compound, N.M. Joshi Marg, Mahalaxmi, Mumbai-400011.
# Regd. Off: Lodha Excelus, 13th Floor, Apollo Mills Compound, N. M. Joshi Marg, Mahalaxmi, Mumbai - 400
# 011.
# Call 1860-267-9999 (local charges apply). DO NOT prefix any country code e.g. +91 or 00. Available Mon- Sat
# from 10 am to 7 pm | Email – service@hdfclife.com | NRIservice@hdfclife.com (For NRI customers only) Visit
# – www.hdfclife.com . CIN: L65110MH2000PLC128245. - 613
#
# POLICY DOCUMENT- HDFC LIFE EASY HEALTH
#
# Unique Identification Number: <<101N110V03>>
#
#  Your Policy is a Single Premium paying non participating non linked fixed benefit health plan. This document is
# the evidence of a contract between HDFC Life Insurance Company Limited and the Policyholder as described in
# the Policy Schedule given below. This Policy is based on the Proposal made by the within named Policyholder
# and submitted to the Company along with the required documents, declarations, statements,  any response given
# to the Short Medical Questionnaire (SMQ) by the Life Assured, and other information received by the Company
# from the Policyholder, Life Assured or on behalf of the Policyholder. This Policy is effective upon receipt and
# realisation, by the Company, of the consideration payable as Premium under the Policy. This Policy is written
# under and will be governed by the applicable laws in force in India and all Premiums and Benefits are expressed - 977

# %% [markdown]
# ### [Text Embedding Models](https://python.langchain.com/docs/modules/data_connection/text_embedding/)
#
# The Embeddings class is a class designed for interfacing with text embedding models. LangChain provides support for most of the embedding model providers (OpenAI, Cohere) including sentence transformers library from Hugging Face.
#
# Embeddings create a vector representation of a piece of text and supports all the operations such as similarity search, text comparison, sentiment analysis etc.
#
# The base Embeddings class in LangChain provides two methods: one for embedding documents and one for embedding a query.
#
# The first method takes as input multiple texts, while the second method returns the embedding representation for a single text.

# %%
# Import the OpenAI Embeddings class from LangChain
from langchain.embeddings import OpenAIEmbeddings
embeddings_model = OpenAIEmbeddings()
# Out:
# /var/folders/zb/k2t8hlmd5dvdmm3x0ghg7m7w0000gq/T/ipykernel_8197/2901031570.py:3: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings_model = OpenAIEmbeddings()

# %%
# doing a sample embedding of a random chunk, to check size
embeddings = embeddings_model.embed_documents([splits[0].page_content])
len(embeddings), len(embeddings[0])
# Out:
# (1, 1536)

# %%
type(embeddings)
# Out:
# list

# %% [markdown]
# ### Vector Stores
#
# One of the most common ways to store and search over unstructured data is to embed it and store the resulting embedding vectors, and then at query time to embed the unstructured query and retrieve the embedding vectors that are 'most similar' to the embedded query. A vector store takes care of storing embedded data and performing vector search for you.

# %%
from langchain.vectorstores import Chroma
# Initialize OpenAIEmbeddings
openai_embeddings = OpenAIEmbeddings()

# %%
# creating a cache backed embeddings
from langchain.storage import InMemoryStore
from langchain.embeddings import CacheBackedEmbeddings

cache_store = InMemoryStore()
cached_embeddings = CacheBackedEmbeddings.from_bytes_store(
    openai_embeddings,
    cache_store,
    namespace="embeddings_namespace"
)

# %%
# Create a persistent ChromaDB instance with OpenAI embeddings
db = Chroma.from_documents(
    documents = splits,
    embedding = cached_embeddings,
    persist_directory="./chroma_persistence"  # Set a directory for persistent storage
)

# %% [markdown]
# Perform Similarity Search

# %%
def similarity_search(query):
    return db.similarity_search(query)

docs =  similarity_search("what is the life insurance coverage for disability?")
print(docs[0])
# Out:
# page_content='Page 7 of 31
#
# Part C
# 1. Benefits:
#
# (1) Benefits on Death or diagnosis of contingency covered –
#
# Plan Option Events Benefit
# Life Death In the event of the death of the Scheme Member, the
# benefit payable shall be the Sum Assured.
# Extra Life Option Death In the event of the death of the Scheme Member, the
# benefit payable shall be the Sum Assured.
# Accidental Death In event of the Scheme Member’s death due to
# Accident, an additional death benefit equal to the Sum
# Assured will be payable.
# This is in addition to the death benefit mentioned
# above
# Accelerated Critical Illness
# Option
#
# Death In the event of the death of the Scheme Member, the
# benefit payable shall be the Sum Assured.
# Diagnosis of a
# Critical Illness
# In the event of Scheme Member being diagnosed with
# any of the covered Critical Illnesses during the Policy
# Term, the benefit payable shall be the Sum Assured
# and the policy will terminate.' metadata={'page': 6, 'source': 'Policy+Documents/HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf'}

# %% [markdown]
# LangChain also support all major vector stores and databases such as FAISS, ElasticSearch, LanceDB, Milvus, Pinecone etc. Refer to the [API documentation](https://api.python.langchain.com/en/latest/api_reference.html#module-langchain.vectorstores) for the complete list.

# %% [markdown]
# ### **Retrievers**
# Retrievers provide Easy way to combine documents with language models.
#
#
# A retriever is an interface that returns documents given an unstructured query. It is more general than a vector store. A retriever does not need to be able to store documents, only to return (or retrieve) them. Retriever stores data for it to be queried by a language model. It provides an interface that will return documents based on an unstructured query. Vector stores can be used as the backbone of a retriever, but there are other types of retrievers as well.
#
#
#
# There are many different types of retrievers, the most widely supported is the VectoreStoreRetriever.
#
# The [official documentation](https://python.langchain.com/docs/integrations/retrievers/) and [API reference](https://api.python.langchain.com/en/latest/api_reference.html#module-langchain.retrievers) contains a list of retriever integrations supported by LangChan.

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import CrossEncoderReranker
from langchain_community.cross_encoders import HuggingFaceCrossEncoder

# Initialize a document retriever using the existing vector storage (db).
# The retriever is configured to retrieve a top 20 documents with  mmr score more than 0.8 with cross encoding enabled

def get_retriever(topk):
    search_kwargs={"k": topk, "score_threshold": 0.8}
    retriever = db.as_retriever(search_type="mmr", search_kwargs=search_kwargs)

    # Initialize cross-encoder model
    cross_encoder = HuggingFaceCrossEncoder(model_name="BAAI/bge-reranker-base")
    
    # Set up reranker
    reranker = CrossEncoderReranker(model=cross_encoder, top_n=20)
    return ContextualCompressionRetriever(base_compressor=reranker, base_retriever=retriever)

    

# Combine retriever and reranker
def get_topk_relevant_documents(query, topk):
    retriever = get_retriever(topk)
    relevant_docs = retriever.invoke(query)
    return relevant_docs

# %%
retriever_docs = get_topk_relevant_documents("what is the life insurance coverage for disability?", 50)

# %%
#len(retriever_docs)
# !pip show langchain
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Name: langchain
# Version: 0.3.13
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /opt/anaconda3/lib/python3.12/site-packages
# Requires: aiohttp, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-community

# %%
# print one page content
retriever_docs[0]
# Out:
# Document(metadata={'page': 13, 'source': 'Policy+Documents/HDFC-Life-Group-Poorna-Suraksha-101N137V02-Policy-Document.pdf'}, page_content='Page 14 of 31 \n \nPart F \n \n1. Waiting Period and Exclusions: \ni. 90 Days Waiting Period for Accelerated Critical Illness Benefit \nNo benefit shall be paid in case the Scheme Member is diagnosed with any of the applicable listed Critical \nIllnesses or surgeries within 90 days from the date of commencement of the Coverage term except in cases \nwhere the Critical Illness occurs as a result of an Accident (such as Major Head Trauma). \n \nii. Suicide exclusion (Single & Joint Life) \n\uf0b7 For employer-employee groups, sum Assured will be payable to the nominee in case of death due to \nSuicide. \n\uf0b7 In case of non employer-employee schemes, if the Scheme Member dies due to suicide within 12 \nmonths from the date of joining the scheme or from the date of revival of the policy, as applicable, the \nnominee or beneficiary of the Scheme Member shall be entitled to at least 80% of the total premiums')

# %%
# method for combining all relevant page content
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
from langchain import hub
prompt = hub.pull("rlm/rag-prompt")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/langsmith/client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %% [markdown]
# # 4. Chains
#
# Using an LLM in isolation is fine for simple applications, but more complex applications require chaining LLMs - either with each other or with other components.
#
# LangChain provides Chains that can be used to combine multiple components together to create a single, coherent application.
#
# For example, we can create a chain that takes user input, formats it with a PromptTemplate, and then passes the formatted response to an LLM. We can build more complex chains by combining multiple chains together, or by combining chains with other components.
#
# The fundamental unit of Chains is a LLMChain object which takes an input and provides an output.

# %%
# In LangChain, the rag-prompt is a prompt template designed for Retrieval-Augmented Generation (RAG) tasks, 
# such as chat and question-answering applications. It facilitates the integration of external context into 
# the language model's responses, enhancing the relevance and accuracy of the generated content.

# pulling rag prompt from LangChain hub
from langchain import hub
prompt = hub.pull("rlm/rag-prompt")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/langsmith/client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %% [markdown]
# Let's now create a simple LLMChain that takes an input, formats it, and passes it to an LLM for processing. The basic components are PromptTemplate, input queries, an LLM, and optional output parsers.

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI()

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

retriever = get_retriever(50)
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# test a query
query = "what is the minimum age for doing a term insurance?"
rag_chain.invoke(query)
# Out:
# 'The minimum age for entry into term insurance is 18 years old as per the Policy Schedule.'

# %%
# test a query
query = "Can a 100 year plus person do a term insurance?"
rag_chain.invoke(query)
# Out:
# 'A person who is 100 years or older may not be eligible for a term insurance policy due to age restrictions set by insurance companies. The insurer can request proof of age at any time and may adjust the policy terms accordingly based on the age of the insured. It is advisable to refer to the Insurance Laws (Amendment) Act, 2015 for complete details on age-related policies.'

# %%
# test another query
query = "what is condition of deatht while not wearing Seat Belt?"
rag_chain.invoke(query)
# Out:
# 'The condition of death while not wearing a seatbelt would likely fall under the exclusion of participating in hazardous activities or sports, as mentioned in the context regarding the conditions for accidental death coverage. It is important to note that not wearing a seatbelt can increase the risk of serious injury or death in the event of a car accident. The specific details of coverage and exclusions would depend on the terms of the insurance policy or relevant legal regulations.'

# %%
# test another query
query = "what is the life insurance coverage for disability?"
rag_chain.invoke(query)
# Out:
# 'The life insurance coverage for disability includes benefits such as Daily Hospital Cash Benefit Option, Surgical Benefit Option, and Critical Illness Benefit Option. In the event of death or diagnosis of a covered contingency, the benefit payable is the Sum Assured. The policy offers various plan options with different benefits based on the chosen options.'

# %%
# test another query
query = "what is criteria for HDFC group insurance?"
rag_chain.invoke(query)
# Out:
# 'The criteria for HDFC group insurance include coverage for eligible members as per the policy terms and conditions, with the policy prevailing in case of any inconsistencies. HDFC Life Group Term Life is a non-linked, non-participating policy, and exclusions such as intentional self-inflicted injury, substance abuse, war, and pre-existing conditions apply. The policy also outlines specific exclusions related to treatments and their complications.'

# %%
# test another query
query = "what are the benifits of HDFC Sampoorna-Jeevan insurance?"
rag_chain.invoke(query)
# Out:
# "The benefits of HDFC Sampoorna-Jeevan insurance include non-linked participating individual life insurance savings, entitlement to participate in the company's profits, and options for lump sum or income benefits on maturity. The policy also offers guaranteed income benefits and bonus options based on the chosen plan. The benefits are subject to the terms and conditions outlined in the policy document and schedule."

# %%
# test another query
query = "what are HDFC Life Sanchay Plus Life Long Income Option ?"
rag_chain.invoke(query)
# Out:
# 'HDFC Life Sanchay Plus Life Long Income Option is a part of the HDFC Life Sanchay Plus plan, which is a non-participating, non-linked savings insurance plan. It provides a life-long income option to policyholders. Additional servicing charges are not applicable in this policy.'
